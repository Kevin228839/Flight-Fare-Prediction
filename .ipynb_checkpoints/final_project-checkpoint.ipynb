# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import warnings
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, learning_curve, GridSearchCV, cross_val_score, RandomizedSearchCV, StratifiedKFold
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import f_regression, SelectKBest, SelectFwe
from sklearn.preprocessing import PolynomialFeatures
# Out:
# C:\Users\rickr\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# ingore warning
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Data Preprocessing

# %%
def CheckWeekend(year, month, day):
    convertDate = datetime.date(year, month, day)
    convertDateResult = convertDate.weekday()
    if convertDateResult <= 4:
        return False
    return True

# import dataset
df = pd.read_excel("Data_Train.xlsx", engine='openpyxl')

# drop null value
df.dropna(inplace=True)

# drop duplicates
df.drop_duplicates(keep='first', inplace=True)

# convert Dep_Time and Arrival_Time into hour and minute
# Dep_Time
df["Dep_hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
df["Dep_minute"] = pd.to_datetime(df["Dep_Time"]).dt.minute
df = df.drop(columns="Dep_Time")

# Arrival_Time
df["Arr_hour"] = pd.to_datetime(df["Arrival_Time"]).dt.hour
df["Arr_minute"] = pd.to_datetime(df["Arrival_Time"]).dt.minute
df = df.drop(columns="Arrival_Time")

# convert Date_of_Journey into timestamp
df["Date_of_Journey_Year"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.year
# ps. I don't think "year" is mandatory
df["Date_of_Journey_Month"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.month
df["Date_of_Journey_Day"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.day
df = df.drop(columns="Date_of_Journey")


# convert Duration into minute
df['Duration'] = df['Duration']\
    .str.replace("h", '*60')\
    .str.replace(' ', '+')\
    .str.replace('m', '*1')\
    .apply(eval)

# drop Additional_Info 
df.drop(['Additional_Info'], axis=1, inplace=True)

# drop Route
df.drop(['Route'], axis=1, inplace=True) 

# Encode categorical attributes
# Select categorical data
df_categorical = df[['Airline', 'Source', 'Destination']]
df.drop(['Airline', 'Source', 'Destination'], axis=1, inplace=True)


# Encode
df_categorical = pd.get_dummies(df_categorical, drop_first=True)
df['Total_Stops'] = df['Total_Stops'].map({"non-stop":0, "1 stop": 1, "2 stops": 2, "3 stops":3, "4 stops": 4})

# Concat categorical and numerical data
preprocessed = pd.concat([df, df_categorical], axis=1)
target = df['Price']

# Drop 'Price' because price is the target variable
preprocessed.drop(['Price'], axis=1, inplace=True)

## Feature Engineering - check if date is weekday or weekend
preprocessed["IsWeekend"] = preprocessed.apply(lambda x: 1 if CheckWeekend(x["Date_of_Journey_Year"], x["Date_of_Journey_Month"], x["Date_of_Journey_Day"]) else 0, axis=1)

# %% [markdown]
# # 2. Model Training & Performance

# %%
# Train_Test_Split
data_train, data_test, target_train, target_test = train_test_split(
    preprocessed, target,test_size=0.3, random_state=42)

# %%
data_train.head()
# Out:
#       Duration  Total_Stops  Dep_hour  Dep_minute  Arr_hour  Arr_minute  \
# 5050      1830            3        16          45        23          15
# 4879       480            1        13           0        21           0
# 208        570            1        14           5        23          35
# 8561       930            1        10           0         1          30
# 7265       165            0        22          10         0          55
#
#       Date_of_Journey_Year  Date_of_Journey_Month  Date_of_Journey_Day  \
# 5050                  2019                      4                    1
# 4879                  2019                      6                    1
# 208                   2019                      5                   21
# 8561                  2019                      6                    9
# 7265                  2019                      3                   21
#
#       Airline_Air India  ...  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 5050                  1  ...               0             0               1
# 4879                  0  ...               0             1               0
# 208                   0  ...               0             0               1
# 8561                  0  ...               0             1               0
# 7265                  0  ...               0             0               1
#
#       Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 5050              0                   0                  0
# 4879              0                   1                  0
# 208               0                   0                  0
# 8561              0                   1                  0
# 7265              0                   0                  0
#
#       Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 5050                      0                    0                      0
# 4879                      0                    0                      0
# 208                       0                    0                      0
# 8561                      0                    0                      0
# 7265                      0                    0                      0
#
#       IsWeekend
# 5050          0
# 4879          1
# 208           0
# 8561          1
# 7265          0
#
# [5 rows x 30 columns]

# %%
data_test.head()
# Out:
#       Duration  Total_Stops  Dep_hour  Dep_minute  Arr_hour  Arr_minute  \
# 2150      1455            1         8           0         8          15
# 3784       140            0        22          20         0          40
# 714        170            0         5          30         8          20
# 7558        90            0        15          50        17          20
# 7413       170            0         9          30        12          20
#
#       Date_of_Journey_Year  Date_of_Journey_Month  Date_of_Journey_Day  \
# 2150                  2019                      3                    6
# 3784                  2019                      6                    6
# 714                   2019                      3                   18
# 7558                  2019                      3                   24
# 7413                  2019                      4                   27
#
#       Airline_Air India  ...  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 2150                  0  ...               0             0               0
# 3784                  0  ...               0             0               1
# 714                   0  ...               0             0               1
# 7558                  0  ...               0             0               0
# 7413                  0  ...               0             0               0
#
#       Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 2150              0                   0                  0
# 3784              0                   0                  0
# 714               0                   0                  0
# 7558              1                   0                  0
# 7413              0                   0                  1
#
#       Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 2150                      0                    0                      1
# 3784                      0                    0                      0
# 714                       0                    0                      0
# 7558                      1                    0                      0
# 7413                      0                    0                      0
#
#       IsWeekend
# 2150          0
# 3784          0
# 714           0
# 7558          1
# 7413          1
#
# [5 rows x 30 columns]

# %%
# normalize 'duration'

# Copy data
data_train_normalize = data_train.copy()
data_test_normalize = data_test.copy()

# create the normaliser
scaler = preprocessing.StandardScaler()
data_train_normalize[['Duration']] = scaler.fit_transform(data_train_normalize[['Duration']])
data_test_normalize[['Duration']] = scaler.fit_transform(data_test_normalize[['Duration']])

data_train_normalize.head()
# Out:
#       Duration  Total_Stops  Dep_hour  Dep_minute  Arr_hour  Arr_minute  \
# 5050  2.408958            3        16          45        23          15
# 4879 -0.303560            1        13           0        21           0
# 208  -0.122725            1        14           5        23          35
# 8561  0.600613            1        10           0         1          30
# 7265 -0.936481            0        22          10         0          55
#
#       Date_of_Journey_Year  Date_of_Journey_Month  Date_of_Journey_Day  \
# 5050                  2019                      4                    1
# 4879                  2019                      6                    1
# 208                   2019                      5                   21
# 8561                  2019                      6                    9
# 7265                  2019                      3                   21
#
#       Airline_Air India  ...  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 5050                  1  ...               0             0               1
# 4879                  0  ...               0             1               0
# 208                   0  ...               0             0               1
# 8561                  0  ...               0             1               0
# 7265                  0  ...               0             0               1
#
#       Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 5050              0                   0                  0
# 4879              0                   1                  0
# 208               0                   0                  0
# 8561              0                   1                  0
# 7265              0                   0                  0
#
#       Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 5050                      0                    0                      0
# 4879                      0                    0                      0
# 208                       0                    0                      0
# 8561                      0                    0                      0
# 7265                      0                    0                      0
#
#       IsWeekend
# 5050          0
# 4879          1
# 208           0
# 8561          1
# 7265          0
#
# [5 rows x 30 columns]

# %%
# score function
def cal_score(model, normalize=False):
    if normalize:
        X_test = data_test_normalize
    else:
        X_test = data_test
        
    predictions = model.predict(X_test)
    
    # R-Squared
    R2_score = r2_score(target_test, predictions)
    R2_scores.append(R2_score)
    print('R-squared: ' + str(R2_score))

    # MAE
    MAE_score = mean_absolute_error(predictions, target_test)
    MAE_scores.append(MAE_score)
    print("MAE : " + str(MAE_score))

    # MSE
    MSE_score = mean_squared_error(predictions, target_test)
    MSE_scores.append(MSE_score)
    print("MSE : " + str(MSE_score))

    # RMSE
    RMSE_score = mean_squared_error(predictions, target_test, squared=False)
    RMSE_scores.append(RMSE_score)
    print("RMSE : " + str(RMSE_score))

# %%
def reverse_scores():
    R2_scores.pop()
    MAE_scores.pop()
    MSE_scores.pop()
    RMSE_scores.pop()

# %%
R2_scores = []
MAE_scores = []
MSE_scores = []
RMSE_scores = []

# %% [markdown]
# ### 1. Linear Regression

# %% [markdown]
# #### 1-1. Model Training

# %%
linear_regression_model = LinearRegression()
linear_regression_model.fit(data_train, target_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### 1-2. Performance

# %%
cal_score(linear_regression_model)
# Out:
# R-squared: 0.6115210423588688
# MAE : 1975.6575667534962
# MSE : 8068160.153310797
# RMSE : 2840.4506954550006

# %% [markdown]
# #### 1-3. Analysis

# %%
# Calculate the number of samples and predictors
n = len(target_test)
p = data_test.shape[1]

# Calculate adjusted R-squared
adjusted_r2 = 1 - (1 - R2_scores[0]) * (n - 1) / (n - p - 1)

# Print the adjusted R-squared score
print("Adjusted R-Squared (Adjusted R^2):", adjusted_r2)
# Out:
# Adjusted R-Squared (Adjusted R^2): 0.6077712454704409

# %%
# Average value of the dependent variable, if all independent variables have the value 0 or are not considered

print("Intercept:",linear_regression_model.intercept_)
# Out:
# Intercept: 6991.540366260865

# %%
# Coefficients for each feature

print(linear_regression_model.coef_)
# Out:
# [ 4.76469189e-02  2.83376931e+03  2.30901694e+01 -1.30917910e+00
#  -6.35968780e+00  3.11882488e+00 -3.54134500e-11 -4.06915554e+02
#  -7.32694139e+01  1.60431228e+03 -3.20685683e+01  2.60489394e+02
#   4.45856510e+03  4.66212381e+04  3.83652042e+03  4.06498502e+03
#  -2.04231800e+02 -1.81898940e-12  2.11016359e+03  2.84863462e+03
#   6.17196021e+01 -1.10967736e+01 -1.23065878e+02 -8.13110340e+02
#  -1.10967736e+01 -8.46726376e+02 -8.13110340e+02  6.17196021e+01
#   1.73227977e+03  2.12502689e+02]

# %%
# Plotting the linear regression
plt.scatter(target_train, linear_regression_model.predict(data_train), color='red', label='Training Set')
plt.scatter(target_test, linear_regression_model.predict(data_test), color='blue', label='Test Set')
plt.plot([target_test.min(), target_test.max()], [target_test.min(), target_test.max()], 'k--', lw=2)
plt.xlabel('Actual Fare')
plt.ylabel('Predicted Fare')
plt.title('Actual vs. Predicted Fare')
plt.legend()
plt.show()

# %% [markdown]
# ### 2. Polynomial Regression

# %% [markdown]
# #### 2-1. Model Training

# %%
# create a transformer
transformer = PolynomialFeatures(degree=2, include_bias=False)

best = SelectFwe(f_regression, alpha=0.05)
estimator = LinearRegression()

poly_regression_model = Pipeline([ ('transformer', transformer), ('feature_selection', best), ('estimator', estimator)])

# fit the regression on the training data
poly_regression_model.fit(data_train_normalize, target_train)
# Out:
# Pipeline(steps=[('transformer', PolynomialFeatures(include_bias=False)),
#                 ('feature_selection',
#                  SelectFwe(score_func=<function f_regression at 0x000002C81F6265E0>)),
#                 ('estimator', LinearRegression())])

# %% [markdown]
# #### 2-2. Performance

# %%
cal_score(poly_regression_model, normalize=True)
# Out:
# R-squared: 0.6850028199290117
# MAE : 1782.1618349284488
# MSE : 6542047.250347469
# RMSE : 2557.742608306682

# %% [markdown]
# #### 2-3. Analysis

# %%
# create a transformer
transformer = PolynomialFeatures(degree=2, include_bias=False)

# run the F-Test
f, pval = f_regression(transformer.fit_transform(data_train), target_train)

# prepare a dataframe to inspect the results
stat = pd.DataFrame({ 'feature': transformer.get_feature_names_out(data_train.columns), 'F value': f, 'p value': pval })
stat['p value'] = round(stat['p value'], 2)

# show the results
display(stat)
# Out:
#                                        feature      F value  p value
# 0                                     Duration  2418.001683     0.00
# 1                                  Total_Stops  4080.632555     0.00
# 2                                     Dep_hour     1.997667     0.16
# 3                                   Dep_minute     4.815703     0.03
# 4                                     Arr_hour     7.350185     0.01
# ..                                         ...          ...      ...
# 490  Destination_Kolkata Destination_New Delhi     0.000000     1.00
# 491              Destination_Kolkata IsWeekend    50.370959     0.00
# 492                    Destination_New Delhi^2   302.040290     0.00
# 493            Destination_New Delhi IsWeekend    13.395025     0.00
# 494                                IsWeekend^2     4.166383     0.04
#
# [495 rows x 3 columns]

# %%
# get the selected features
selected_features = poly_regression_model.named_steps['feature_selection'].get_support()

# print the selected variables
for i, f in enumerate(poly_regression_model.named_steps['transformer'].get_feature_names_out(data_train.columns)):
    if selected_features[i]:
        print(f)
# Out:
# Duration
# Total_Stops
# Arr_minute
# Date_of_Journey_Month
# Date_of_Journey_Day
# Airline_Air India
# Airline_GoAir
# Airline_IndiGo
# Airline_Jet Airways
# Airline_Jet Airways Business
# Airline_Multiple carriers
# Airline_SpiceJet
# Airline_Vistara
# Source_Chennai
# Source_Delhi
# Source_Mumbai
# Destination_Cochin
# Destination_Delhi
# Destination_Hyderabad
# Destination_Kolkata
# Destination_New Delhi
# Duration^2
# Duration Total_Stops
# Duration Dep_hour
# Duration Dep_minute
# Duration Arr_hour
# Duration Arr_minute
# Duration Date_of_Journey_Year
# Duration Date_of_Journey_Month
# Duration Date_of_Journey_Day
# Duration Airline_Air India
# Duration Airline_GoAir
# Duration Airline_IndiGo
# Duration Airline_Jet Airways
# Duration Airline_Jet Airways Business
# Duration Airline_SpiceJet
# Duration Airline_Vistara
# Duration Source_Chennai
# Duration Source_Delhi
# Duration Source_Kolkata
# Duration Source_Mumbai
# Duration Destination_Cochin
# Duration Destination_Delhi
# Duration Destination_Hyderabad
# Duration Destination_Kolkata
# Duration Destination_New Delhi
# Duration IsWeekend
# Total_Stops^2
# Total_Stops Dep_hour
# Total_Stops Dep_minute
# Total_Stops Arr_hour
# Total_Stops Arr_minute
# Total_Stops Date_of_Journey_Year
# Total_Stops Date_of_Journey_Month
# Total_Stops Date_of_Journey_Day
# Total_Stops Airline_Air India
# Total_Stops Airline_GoAir
# Total_Stops Airline_IndiGo
# Total_Stops Airline_Jet Airways
# Total_Stops Airline_Jet Airways Business
# Total_Stops Airline_Multiple carriers
# Total_Stops Airline_SpiceJet
# Total_Stops Source_Delhi
# Total_Stops Source_Kolkata
# Total_Stops Source_Mumbai
# Total_Stops Destination_Cochin
# Total_Stops Destination_Hyderabad
# Total_Stops Destination_New Delhi
# Total_Stops IsWeekend
# Dep_hour Arr_minute
# Dep_hour Date_of_Journey_Day
# Dep_hour Airline_GoAir
# Dep_hour Airline_IndiGo
# Dep_hour Airline_Jet Airways
# Dep_hour Airline_Jet Airways Business
# Dep_hour Airline_Multiple carriers
# Dep_hour Airline_SpiceJet
# Dep_hour Airline_Vistara
# Dep_hour Source_Chennai
# Dep_hour Source_Delhi
# Dep_hour Source_Mumbai
# Dep_hour Destination_Cochin
# Dep_hour Destination_Delhi
# Dep_hour Destination_Hyderabad
# Dep_hour Destination_Kolkata
# Dep_hour Destination_New Delhi
# Dep_minute Date_of_Journey_Month
# Dep_minute Date_of_Journey_Day
# Dep_minute Airline_Air India
# Dep_minute Airline_GoAir
# Dep_minute Airline_IndiGo
# Dep_minute Airline_Jet Airways
# Dep_minute Airline_Jet Airways Business
# Dep_minute Airline_Multiple carriers
# Dep_minute Airline_SpiceJet
# Dep_minute Source_Chennai
# Dep_minute Source_Delhi
# Dep_minute Source_Mumbai
# Dep_minute Destination_Cochin
# Dep_minute Destination_Delhi
# Dep_minute Destination_Hyderabad
# Dep_minute Destination_Kolkata
# Dep_minute Destination_New Delhi
# Arr_hour Arr_minute
# Arr_hour Date_of_Journey_Day
# Arr_hour Airline_GoAir
# Arr_hour Airline_IndiGo
# Arr_hour Airline_Jet Airways
# Arr_hour Airline_Jet Airways Business
# Arr_hour Airline_Multiple carriers
# Arr_hour Airline_SpiceJet
# Arr_hour Airline_Vistara
# Arr_hour Source_Chennai
# Arr_hour Source_Delhi
# Arr_hour Source_Mumbai
# Arr_hour Destination_Cochin
# Arr_hour Destination_Delhi
# Arr_hour Destination_Hyderabad
# Arr_hour Destination_Kolkata
# Arr_hour Destination_New Delhi
# Arr_minute^2
# Arr_minute Date_of_Journey_Year
# Arr_minute Date_of_Journey_Month
# Arr_minute Date_of_Journey_Day
# Arr_minute Airline_GoAir
# Arr_minute Airline_IndiGo
# Arr_minute Airline_Jet Airways
# Arr_minute Airline_Jet Airways Business
# Arr_minute Airline_Multiple carriers
# Arr_minute Airline_SpiceJet
# Arr_minute Airline_Vistara
# Arr_minute Source_Chennai
# Arr_minute Source_Delhi
# Arr_minute Source_Mumbai
# Arr_minute Destination_Cochin
# Arr_minute Destination_Delhi
# Arr_minute Destination_Hyderabad
# Arr_minute Destination_Kolkata
# Arr_minute Destination_New Delhi
# Date_of_Journey_Year Date_of_Journey_Month
# Date_of_Journey_Year Date_of_Journey_Day
# Date_of_Journey_Year Airline_Air India
# Date_of_Journey_Year Airline_GoAir
# Date_of_Journey_Year Airline_IndiGo
# Date_of_Journey_Year Airline_Jet Airways
# Date_of_Journey_Year Airline_Jet Airways Business
# Date_of_Journey_Year Airline_Multiple carriers
# Date_of_Journey_Year Airline_SpiceJet
# Date_of_Journey_Year Airline_Vistara
# Date_of_Journey_Year Source_Chennai
# Date_of_Journey_Year Source_Delhi
# Date_of_Journey_Year Source_Mumbai
# Date_of_Journey_Year Destination_Cochin
# Date_of_Journey_Year Destination_Delhi
# Date_of_Journey_Year Destination_Hyderabad
# Date_of_Journey_Year Destination_Kolkata
# Date_of_Journey_Year Destination_New Delhi
# Date_of_Journey_Month^2
# Date_of_Journey_Month Date_of_Journey_Day
# Date_of_Journey_Month Airline_GoAir
# Date_of_Journey_Month Airline_IndiGo
# Date_of_Journey_Month Airline_Jet Airways
# Date_of_Journey_Month Airline_Jet Airways Business
# Date_of_Journey_Month Airline_Multiple carriers
# Date_of_Journey_Month Airline_SpiceJet
# Date_of_Journey_Month Airline_Vistara
# Date_of_Journey_Month Source_Chennai
# Date_of_Journey_Month Source_Delhi
# Date_of_Journey_Month Source_Mumbai
# Date_of_Journey_Month Destination_Cochin
# Date_of_Journey_Month Destination_Delhi
# Date_of_Journey_Month Destination_Hyderabad
# Date_of_Journey_Month Destination_Kolkata
# Date_of_Journey_Month Destination_New Delhi
# Date_of_Journey_Day^2
# Date_of_Journey_Day Airline_GoAir
# Date_of_Journey_Day Airline_IndiGo
# Date_of_Journey_Day Airline_Jet Airways
# Date_of_Journey_Day Airline_Jet Airways Business
# Date_of_Journey_Day Airline_Multiple carriers
# Date_of_Journey_Day Airline_SpiceJet
# Date_of_Journey_Day Airline_Vistara
# Date_of_Journey_Day Source_Chennai
# Date_of_Journey_Day Source_Delhi
# Date_of_Journey_Day Source_Mumbai
# Date_of_Journey_Day Destination_Cochin
# Date_of_Journey_Day Destination_Delhi
# Date_of_Journey_Day Destination_Hyderabad
# Date_of_Journey_Day Destination_Kolkata
# Airline_Air India^2
# Airline_Air India Source_Delhi
# Airline_Air India Source_Kolkata
# Airline_Air India Source_Mumbai
# Airline_Air India Destination_Cochin
# Airline_Air India Destination_Delhi
# Airline_Air India Destination_Hyderabad
# Airline_Air India Destination_New Delhi
# Airline_GoAir^2
# Airline_GoAir Source_Delhi
# Airline_GoAir Destination_Cochin
# Airline_GoAir Destination_Delhi
# Airline_GoAir IsWeekend
# Airline_IndiGo^2
# Airline_IndiGo Source_Chennai
# Airline_IndiGo Source_Delhi
# Airline_IndiGo Source_Kolkata
# Airline_IndiGo Source_Mumbai
# Airline_IndiGo Destination_Cochin
# Airline_IndiGo Destination_Delhi
# Airline_IndiGo Destination_Hyderabad
# Airline_IndiGo Destination_Kolkata
# Airline_IndiGo IsWeekend
# Airline_Jet Airways^2
# Airline_Jet Airways Source_Delhi
# Airline_Jet Airways Source_Kolkata
# Airline_Jet Airways Source_Mumbai
# Airline_Jet Airways Destination_Cochin
# Airline_Jet Airways Destination_Delhi
# Airline_Jet Airways Destination_Hyderabad
# Airline_Jet Airways Destination_New Delhi
# Airline_Jet Airways IsWeekend
# Airline_Jet Airways Business^2
# Airline_Jet Airways Business Source_Delhi
# Airline_Jet Airways Business Destination_Cochin
# Airline_Jet Airways Business Destination_New Delhi
# Airline_Jet Airways Business IsWeekend
# Airline_Multiple carriers^2
# Airline_Multiple carriers Source_Delhi
# Airline_Multiple carriers Destination_Cochin
# Airline_Multiple carriers IsWeekend
# Airline_SpiceJet^2
# Airline_SpiceJet Source_Chennai
# Airline_SpiceJet Source_Delhi
# Airline_SpiceJet Source_Kolkata
# Airline_SpiceJet Source_Mumbai
# Airline_SpiceJet Destination_Cochin
# Airline_SpiceJet Destination_Delhi
# Airline_SpiceJet Destination_Hyderabad
# Airline_SpiceJet Destination_Kolkata
# Airline_SpiceJet IsWeekend
# Airline_Vistara^2
# Airline_Vistara Destination_Delhi
# Source_Chennai^2
# Source_Chennai Destination_Kolkata
# Source_Chennai IsWeekend
# Source_Delhi^2
# Source_Delhi Destination_Cochin
# Source_Delhi IsWeekend
# Source_Kolkata IsWeekend
# Source_Mumbai^2
# Source_Mumbai Destination_Hyderabad
# Source_Mumbai IsWeekend
# Destination_Cochin^2
# Destination_Cochin IsWeekend
# Destination_Delhi^2
# Destination_Delhi IsWeekend
# Destination_Hyderabad^2
# Destination_Hyderabad IsWeekend
# Destination_Kolkata^2
# Destination_Kolkata IsWeekend
# Destination_New Delhi^2

# %% [markdown]
# ### 3. Regression Tree

# %% [markdown]
# #### 3-1. Model Training without Tuning

# %%
# Initializing the Decision Tree Regression model
rg_tree_basic = DecisionTreeRegressor(random_state = 42)

# Fitting the Decision Tree Regression model to the data
rg_tree_basic.fit(data_train, target_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# #### 3-2. Model Training with hyperparameter tuning

# %%
# specify the parameter grid
parameter_grid = {'max_features': ['auto', 'sqrt'],
          'max_depth':[int(x) for x in np.linspace(start = 1, stop = 20, num = 20)],
          'min_samples_leaf':[int(x) for x in np.linspace(start = 1, stop = 20, num = 20)],
          'min_samples_split':[int(x) for x in np.linspace(start = 1, stop = 20, num = 20)]
         }

regression_tree_model = DecisionTreeRegressor(random_state = 42)
regression_tree_rs = RandomizedSearchCV(random_state = 42, estimator=regression_tree_model, param_distributions=parameter_grid, scoring='neg_mean_squared_error', cv=5, n_iter=10)
regression_tree_rs.fit(data_train, target_train)
print('Best parameters: ',regression_tree_rs.best_params_)
print('Best R-sqaured score: ',regression_tree_rs.best_score_)
# Out:
# Best parameters:  {'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'auto', 'max_depth': 15}
# Best R-sqaured score:  -6511469.989729738

# %% [markdown]
# #### 3-3. Performance

# %%
print("Model without hyperparameter tuning")
print("")

#use cross-validation to estimate model performance
cross_regression_tree = cross_val_score(rg_tree_basic, data_train, target_train, cv=10, scoring='r2')
print('Average Cross-Validation R-squared score: ', cross_regression_tree.mean())


# Predicting the target values of the test set
y_pred = rg_tree_basic.predict(data_test)


#Evaluate the model on the testing set
#r_squared
r2_regression_tree = r2_score(target_test, y_pred)
print('R-Squared:', r2_regression_tree)

#MAE
mean_absolute_error_regression_tree = mean_absolute_error(target_test, y_pred)
print('MAE:', mean_absolute_error_regression_tree)

#MSE
mean_squared_error_regression_tree = mean_squared_error(target_test, y_pred)
print('MSE:', mean_squared_error_regression_tree)

#RMSE
root_mean_squared_error_regression_tree = mean_squared_error(target_test, y_pred, squared=False)
print('RMSE:', root_mean_squared_error_regression_tree)

print("---------------------------------------")

print("Model with hyperparameter tuning")
print("")

cross_regression_tree = cross_val_score(regression_tree_rs, data_train, target_train, cv=10, scoring='r2')
print('Average Cross-Validation R-squared score: ', cross_regression_tree.mean())

cal_score(regression_tree_rs)
# Out:
# Model without hyperparameter tuning
#
# Average Cross-Validation R-squared score:  0.6883334583334569
# R-Squared: 0.6903080744088547
# MAE: 1398.8485451842412
# MSE: 6431864.595777582
# RMSE: 2536.112102368029
# ---------------------------------------
# Model with hyperparameter tuning
#
# Average Cross-Validation R-squared score:  0.7115753408131666
# R-squared: 0.7308717527849882
# MAE : 1317.8458766756773
# MSE : 5589414.195031904
# RMSE : 2364.194195710645

# %% [markdown]
# ### 4. Random Forest

# %% [markdown]
# #### 4-1. Training without Tuning

# %%
rf_model_basic = RandomForestRegressor()
rf_model_basic.fit(data_train, target_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### 4-2. Training with hyperparameter tuning

# %%
# specify the parameter grid
parameter_grid = {
    'max_depth': [int(x) for x in np.linspace(10, 100, 10)],
    'max_features': ['auto', 'sqrt'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'n_estimators': [int(x) for x in np.linspace(50, 500, 10)]
}

# %%
# specify the cross validation
stratified_10_fold_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

rf_model = RandomForestRegressor()
rf_model_rs = RandomizedSearchCV(rf_model, parameter_grid, scoring='neg_mean_squared_error', cv=stratified_10_fold_cv, error_score='raise')

rf_model_rs.fit(data_train, target_train)

# print the results of all hyper-parameter combinations
results = pd.DataFrame(rf_model_rs.cv_results_)
display(results)

# print the best parameter setting
print("Best score is {} with params {}".format(rf_model_rs.best_score_, rf_model_rs.best_params_))
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.083595      0.071471         0.066810        0.001784
# 1       1.077615      0.009052         0.030620        0.000866
# 2       2.904568      0.126563         0.077921        0.002548
# 3       1.567405      0.082455         0.046933        0.002918
# 4       8.077027      0.170848         0.072952        0.004240
# 5       2.908550      0.122021         0.091081        0.007498
# 6       2.681600      0.099363         0.028743        0.002229
# 7      13.267116      0.277868         0.115486        0.006186
# 8       3.054106      0.025270         0.029700        0.001167
# 9       2.030776      0.089466         0.061739        0.006155
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                300                       2                      1
# 1                150                       5                      1
# 2                400                       2                      2
# 3                250                      10                      1
# 4                350                       5                      1
# 5                500                      10                      2
# 6                150                      10                      4
# 7                500                       2                      1
# 8                150                       5                      2
# 9                350                       2                      4
#
#   param_max_features param_max_depth  \
# 0               sqrt              40
# 1               sqrt              70
# 2               sqrt              20
# 3               sqrt              60
# 4               auto              50
# 5               sqrt              30
# 6               auto              30
# 7               auto              20
# 8               auto             100
# 9               sqrt              70
#
#                                               params  ...  split3_test_score  \
# 0  {'n_estimators': 300, 'min_samples_split': 2, ...  ...      -6.612555e+06
# 1  {'n_estimators': 150, 'min_samples_split': 5, ...  ...      -6.509296e+06
# 2  {'n_estimators': 400, 'min_samples_split': 2, ...  ...      -6.995225e+06
# 3  {'n_estimators': 250, 'min_samples_split': 10,...  ...      -6.560145e+06
# 4  {'n_estimators': 350, 'min_samples_split': 5, ...  ...      -6.320795e+06
# 5  {'n_estimators': 500, 'min_samples_split': 10,...  ...      -7.439523e+06
# 6  {'n_estimators': 150, 'min_samples_split': 10,...  ...      -7.646628e+06
# 7  {'n_estimators': 500, 'min_samples_split': 2, ...  ...      -6.281908e+06
# 8  {'n_estimators': 150, 'min_samples_split': 5, ...  ...      -7.678226e+06
# 9  {'n_estimators': 350, 'min_samples_split': 2, ...  ...      -8.639121e+06
#
#    split4_test_score  split5_test_score  split6_test_score  split7_test_score  \
# 0      -4.789333e+06      -3.497048e+06      -3.935726e+06      -5.349328e+06
# 1      -4.472756e+06      -3.290191e+06      -3.725158e+06      -5.270046e+06
# 2      -4.631302e+06      -3.164523e+06      -4.893837e+06      -6.213942e+06
# 3      -4.404616e+06      -3.125239e+06      -3.943556e+06      -5.453124e+06
# 4      -3.889023e+06      -3.465535e+06      -3.877288e+06      -5.583398e+06
# 5      -4.603392e+06      -3.191176e+06      -5.100415e+06      -6.376352e+06
# 6      -3.979911e+06      -2.913038e+06      -6.365880e+06      -7.465448e+06
# 7      -4.064390e+06      -3.690527e+06      -3.960781e+06      -5.848043e+06
# 8      -4.124875e+06      -3.439129e+06      -5.001035e+06      -5.419969e+06
# 9      -4.946989e+06      -3.398287e+06      -6.971526e+06      -7.831701e+06
#
#    split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0      -3.446799e+06      -3.699366e+06    -4.354721e+06    9.901261e+05
# 1      -3.406539e+06      -3.283096e+06    -4.150805e+06    1.034333e+06
# 2      -3.410303e+06      -3.723306e+06    -4.495263e+06    1.243440e+06
# 3      -3.411388e+06      -3.458021e+06    -4.216287e+06    1.075039e+06
# 4      -3.130803e+06      -3.329683e+06    -4.037762e+06    1.054034e+06
# 5      -3.568686e+06      -3.833951e+06    -4.626157e+06    1.333955e+06
# 6      -3.360806e+06      -4.179935e+06    -4.684690e+06    1.737430e+06
# 7      -3.252408e+06      -3.467108e+06    -4.168300e+06    1.010580e+06
# 8      -3.178211e+06      -3.091515e+06    -4.274641e+06    1.395023e+06
# 9      -3.811423e+06      -4.684839e+06    -5.332952e+06    1.773994e+06
#
#    rank_test_score
# 0                6
# 1                2
# 2                7
# 3                4
# 4                1
# 5                8
# 6                9
# 7                3
# 8                5
# 9               10
#
# [10 rows x 23 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 14
#      11 display(results)
#      13 # print the best parameter setting
# ---> 14 print("Best score is {} with params {}".format(rand_search_estimator.best_score_, rand_search_estimator.best_params_))
#
# NameError: name 'rand_search_estimator' is not defined

# %% [markdown]
# #### 4-3. Performance

# %%
print("Model without hyperparameter tuning")
print("")

# Predicting the target values of the test set
y_pred = rf_model_basic.predict(data_test)


#Evaluate the model on the testing set
#r_squared
r2_rf = r2_score(target_test, y_pred)
print('R-Squared:', r2_rf)

#MAE
mean_absolute_error_rf = mean_absolute_error(target_test, y_pred)
print('MAE:', mean_absolute_error_rf)

#MSE
mean_squared_error_rf = mean_squared_error(target_test, y_pred)
print('MSE:', mean_squared_error_rf)

#RMSE
root_mean_squared_error_rf = mean_squared_error(target_test, y_pred, squared=False)
print('RMSE:', root_mean_squared_error_rf)

print("---------------------------------------")

print("Model with hyperparameter tuning")
print("")

cal_score(rf_model_rs)
# Out:
# Model without hyperparameter tuning
#
# R-Squared: 0.814348301944668
# MAE: 1196.4867751874774
# MSE: 3855723.9798512235
# RMSE: 1963.5997504204424
# ---------------------------------------
# Model with hyperparameter tuning
#
# R-squared: 0.8286696220312622
# MAE : 1156.2345834159844
# MSE : 3558290.3562462903
# RMSE : 1886.3431173162242

# %% [markdown]
# #### 4-4. Analysis

# %%
prediction = rf_model_rs.best_estimator_.predict(data_test)

plt.figure(figsize=(8, 8))
plt.scatter(target_test, prediction, alpha=0.5)
plt.xlabel("price_test")
plt.ylabel("price_pred")
plt.show()

# %% [markdown]
# ### 5. XGBoost

# %% [markdown]
# #### 5-1. Training without Tuning

# %%
xgboost_model_basic = XGBRegressor()
xgboost_model_basic.fit(data_train,target_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# #### 5-2. Training with hyperparameter tuning

# %%
# specify the parameter grid
n_estimators_range = list(np.arange(100,501,100))
leaning_rate_range = [0.01, 0.05, 0.1]
max_depth_range = list(np.arange(5,15,1))
reg_lambda_range = [0.001, 0.1, 1.0, 10.0, 100.0]

parameter_grid = {"n_estimators": n_estimators_range, 
                  "learning_rate": leaning_rate_range,
                  "max_depth": max_depth_range,
                  "reg_lambda": reg_lambda_range}

xgboost_model = XGBRegressor()
xgboost_rs = RandomizedSearchCV(xgboost_model, parameter_grid, scoring="neg_mean_squared_error", cv=5)
xgboost_rs.fit(data_train,target_train)

# %% [markdown]
# #### 5-3. Performance

# %%
print("Model without hyperparameter tuning")
print("")

# Predicting the target values of the test set
y_pred = xgboost_model_basic.predict(data_test)


#Evaluate the model on the testing set
#r_squared
r2_rf = r2_score(target_test, y_pred)
print('R-Squared:', r2_rf)

#MAE
mean_absolute_error_rf = mean_absolute_error(target_test, y_pred)
print('MAE:', mean_absolute_error_rf)

#MSE
mean_squared_error_rf = mean_squared_error(target_test, y_pred)
print('MSE:', mean_squared_error_rf)

#RMSE
root_mean_squared_error_rf = mean_squared_error(target_test, y_pred, squared=False)
print('RMSE:', root_mean_squared_error_rf)

print("---------------------------------------")

print("Model with hyperparameter tuning")
print("")

cal_score(xgboost_rs)

# %% [markdown]
# # 3. Comparison

# %%
display(R2_scores)
display(MAE_scores)
display(MSE_scores)
display(RMSE_scores)

# %%
grid_dict = {0: 'Linear Regression', 1: 'Polynomial Regression', 2: 'Regression Tree', 3: 'Random Forest', 4: 'XGBoost'}
for i, model in enumerate(models):
    print('Model {}: {}'.format(i+1, grid_dict[i]))
#     if i != 0:
#         print('{} Best Params: {}'.format(grid_dict[i], model.best_params_))
    print('R-squared: {}'.format(r2_score(target_test, model.predict(data_test))))
    print('MAE: {}'.format(mean_absolute_error(model.predict(data_test), target_test)))
    print('MSE: {}'.format(mean_squared_error(model.predict(data_test), target_test)))
    print('RMSE: {}'.format(mean_squared_error(model.predict(data_test), target_test, squared=False)))
    print('')

# %% [markdown]
# # 4. Learning Curve

# %%
# learning Curve

def draw_learning_curve(model):
    train_errors, val_errors = [], []
    for m in range(1, len(data_train)):
        model.fit(data_train[:m], target_train[:m])
        target_train_predict = model.predict(data_train[:m])
        target_test_predict = model.predict(data_test)
        train_errors.append(mean_squared_error(target_train_predict, target_train[:m]))
        val_errors.append(mean_squared_error(target_test_predict, target_test))
    plt.plot(np.sqrt(train_errors)/1000, "r-", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors)/1000, "b-", linewidth=1, label="val")
    plt.legend(loc="upper right", fontsize=14)
    plt.xlabel("Training set size", fontsize=14)
    plt.ylabel("RMSE (Thousands)", fontsize=14)
    plt.ylim((0, 5))
    plt.show()
    print('')

# %%
# Linear Regression
print("learning curve for linear regression")
draw_learning_curve(linear_regression_model)

# %%
# Poly Regression
print("learning curve for Poly regression")
draw_learning_curve(poly_regression_model)

# %%
# Regression Tree
print("learning curve for Regression Tree")
draw_learning_curve(regression_tree_rs)

# %%
# Random Forest
print("learning curve for Random Forest")
draw_learning_curve(rf_model_rs)

# %%
# XGBoost
print("learning curve for XGBoost")
draw_learning_curve(xgboost_rs)
