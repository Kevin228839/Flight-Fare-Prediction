# %% [markdown]
# # Preprocess

# %%
# Flight fare prediction
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import datetime
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def CheckWeekend(year, month, day):
    convertDate = datetime.date(year, month, day)
    convertDateResult = convertDate.weekday()
    if convertDateResult <= 4:
        return False
    return True

# Preprocessing
# import dataset
df = pd.read_excel("Data_Train.xlsx")

# drop null value
df.dropna(inplace=True)

# drop duplicates
df.drop_duplicates(keep='first', inplace=True)

# convert Dep_Time and Arrival_Time into hour and minute
# Dep_Time
df["Dep_hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
df["Dep_minute"] = pd.to_datetime(df["Dep_Time"]).dt.minute
df = df.drop(columns="Dep_Time")

# Arrival_Time
df["Arr_hour"] = pd.to_datetime(df["Arrival_Time"]).dt.hour
df["Arr_minute"] = pd.to_datetime(df["Arrival_Time"]).dt.minute
df = df.drop(columns="Arrival_Time")

# convert Date_of_Journey into timestamp
df["Date_of_Journey_Year"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.year
# ps. I don't think "year" is mandatory
df["Date_of_Journey_Month"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.month
df["Date_of_Journey_Day"] = pd.to_datetime(
    df["Date_of_Journey"], format="%d/%m/%Y").dt.day
df = df.drop(columns="Date_of_Journey")


# convert Duration into minute
df['Duration'] = df['Duration']\
    .str.replace("h", '*60')\
    .str.replace(' ', '+')\
    .str.replace('m', '*1')\
    .apply(eval)

# drop Additional_Info 
df.drop(['Additional_Info'], axis=1, inplace=True)

# drop Route
df.drop(['Route'], axis=1, inplace=True) 

# Encode categorical attributes
# Select categorical data
df_categorical = df[['Airline', 'Source', 'Destination']]
df.drop(['Airline', 'Source', 'Destination'], axis=1, inplace=True)


# Encode
df_categorical = pd.get_dummies(df_categorical, drop_first=True)
df['Total_Stops'] = df['Total_Stops'].map({"non-stop":0, "1 stop": 1, "2 stops": 2, "3 stops":3, "4 stops": 4})

# Concat categorical and numerical data
preprocessed = pd.concat([df, df_categorical], axis=1)
target = df['Price']

# Drop 'Price' because price is the target variable
preprocessed.drop(['Price'], axis=1, inplace=True)

# Train_Test_Split
data_train, data_test, target_train, target_test = train_test_split(
    preprocessed, target,test_size=0.3, random_state=42)

## Feature Engineering - check if date is weekday or weekend
data_train["IsWeekend"] = data_train.apply(lambda x: 1 if CheckWeekend(x["Date_of_Journey_Year"], x["Date_of_Journey_Month"], x["Date_of_Journey_Day"]) else 0, axis=1)
data_test["IsWeekend"] = data_test.apply(lambda x: 1 if CheckWeekend(x["Date_of_Journey_Year"], x["Date_of_Journey_Month"], x["Date_of_Journey_Day"]) else 0, axis=1)

# %%
# create the normaliser
scaler = preprocessing.StandardScaler()
data_train[['Duration']] = scaler.fit_transform(data_train[['Duration']])
data_test[['Duration']] = scaler.fit_transform(data_test[['Duration']])

# %%
# Copy data
data_train_poly = data_train.copy()
data_test_poly = data_test.copy()
target_train_poly = target_train.copy()
target_test_poly = target_test.copy()

display(data_train_poly.head())
# Out:
#       Duration  Total_Stops  Dep_hour  Dep_minute  Arr_hour  Arr_minute  \
# 5050  2.408958            3        16          45        23          15
# 4879 -0.303560            1        13           0        21           0
# 208  -0.122725            1        14           5        23          35
# 8561  0.600613            1        10           0         1          30
# 7265 -0.936481            0        22          10         0          55
#
#       Date_of_Journey_Year  Date_of_Journey_Month  Date_of_Journey_Day  \
# 5050                  2019                      4                    1
# 4879                  2019                      6                    1
# 208                   2019                      5                   21
# 8561                  2019                      6                    9
# 7265                  2019                      3                   21
#
#       Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 5050                  1              0               0                    0
# 4879                  0              0               0                    0
# 208                   0              0               0                    1
# 8561                  0              0               0                    0
# 7265                  0              0               1                    0
#
#       Airline_Jet Airways Business  Airline_Multiple carriers  \
# 5050                             0                          0
# 4879                             0                          1
# 208                              0                          0
# 8561                             0                          1
# 7265                             0                          0
#
#       Airline_Multiple carriers Premium economy  Airline_SpiceJet  \
# 5050                                          0                 0
# 4879                                          0                 0
# 208                                           0                 0
# 8561                                          0                 0
# 7265                                          0                 0
#
#       Airline_Trujet  Airline_Vistara  Airline_Vistara Premium economy  \
# 5050               0                0                                0
# 4879               0                0                                0
# 208                0                0                                0
# 8561               0                0                                0
# 7265               0                0                                0
#
#       Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai  \
# 5050               0             0               1              0
# 4879               0             1               0              0
# 208                0             0               1              0
# 8561               0             1               0              0
# 7265               0             0               1              0
#
#       Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 5050                   0                  0                      0
# 4879                   1                  0                      0
# 208                    0                  0                      0
# 8561                   1                  0                      0
# 7265                   0                  0                      0
#
#       Destination_Kolkata  Destination_New Delhi  IsWeekend
# 5050                    0                      0          0
# 4879                    0                      0          1
# 208                     0                      0          0
# 8561                    0                      0          1
# 7265                    0                      0          0

# %% [markdown]
# # Polynomial Regression
# ## [F regression](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html)

# %%
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import PolynomialFeatures
import math

# create a transformer
transformer = PolynomialFeatures(degree=2, include_bias=False)

# run the F-Test
f, pval = f_regression(transformer.fit_transform(data_train_poly), target_train_poly)

# prepare a dataframe to inspect the results
stat = pd.DataFrame({ 'feature': transformer.get_feature_names_out(data_train_poly.columns), 'F value': f, 'p value': pval })
stat['p value'] = round(stat['p value'], 2)

# show the results
display(stat)

count = 0
for i in range(len(stat)):
    if(math.isnan(stat['F value'][i])):
        count = count+1
print(count)
# Out:
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:284: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means ** 2)
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: divide by zero encountered in true_divide
#   correlation_coefficient /= X_norms
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:358: RuntimeWarning: invalid value encountered in true_divide
#   f_statistic = corr_coef_squared / (1 - corr_coef_squared) * deg_of_freedom
#                                                feature      F value  p value
# 0                                             Duration  2418.001683     0.00
# 1                                          Total_Stops  4080.632555     0.00
# 2                                             Dep_hour     1.997667     0.16
# 3                                           Dep_minute     4.815703     0.03
# 4                                             Arr_hour     7.350185     0.01
# 5                                           Arr_minute    50.117144     0.00
# 6                                 Date_of_Journey_Year          NaN      NaN
# 7                                Date_of_Journey_Month   105.001763     0.00
# 8                                  Date_of_Journey_Day   190.704621     0.00
# 9                                    Airline_Air India    16.872350     0.00
# 10                                       Airline_GoAir    65.676054     0.00
# 11                                      Airline_IndiGo  1067.178466     0.00
# 12                                 Airline_Jet Airways  1530.357449     0.00
# 13                        Airline_Jet Airways Business   586.830491     0.00
# 14                           Airline_Multiple carriers   157.133032     0.00
# 15           Airline_Multiple carriers Premium economy     2.045936     0.15
# 16                                    Airline_SpiceJet   685.138075     0.00
# 17                                      Airline_Trujet          NaN      NaN
# 18                                     Airline_Vistara    30.835972     0.00
# 19                     Airline_Vistara Premium economy     0.001145     0.97
# 20                                      Source_Chennai   226.644207     0.00
# 21                                        Source_Delhi   484.426614     0.00
# 22                                      Source_Kolkata     2.352964     0.13
# 23                                       Source_Mumbai   404.502471     0.00
# 24                                  Destination_Cochin   484.426614     0.00
# 25                                   Destination_Delhi   744.714290     0.00
# 26                               Destination_Hyderabad   404.502471     0.00
# 27                                 Destination_Kolkata   226.644207     0.00
# 28                               Destination_New Delhi   302.040290     0.00
# 29                                           IsWeekend     4.166383     0.04
# 30                                          Duration^2    52.469122     0.00
# 31                                Duration Total_Stops   644.162813     0.00
# 32                                   Duration Dep_hour  2028.442426     0.00
# 33                                 Duration Dep_minute  1593.099851     0.00
# 34                                   Duration Arr_hour  1542.431825     0.00
# 35                                 Duration Arr_minute  1733.675136     0.00
# 36                       Duration Date_of_Journey_Year  2418.001683     0.00
# 37                      Duration Date_of_Journey_Month  2274.274424     0.00
# 38                        Duration Date_of_Journey_Day  1591.707222     0.00
# 39                          Duration Airline_Air India   246.450590     0.00
# 40                              Duration Airline_GoAir    66.916611     0.00
# 41                             Duration Airline_IndiGo  1018.168231     0.00
# 42                        Duration Airline_Jet Airways   600.547277     0.00
# 43               Duration Airline_Jet Airways Business   547.335513     0.00
# 44                  Duration Airline_Multiple carriers     3.355246     0.07
# 45   Duration Airline_Multiple carriers Premium eco...     0.373145     0.54
# 46                           Duration Airline_SpiceJet   750.731203     0.00
# 47                             Duration Airline_Trujet          NaN      NaN
# 48                            Duration Airline_Vistara    37.893448     0.00
# 49            Duration Airline_Vistara Premium economy     0.000455     0.98
# 50                             Duration Source_Chennai   226.686441     0.00
# 51                               Duration Source_Delhi   338.964313     0.00
# 52                             Duration Source_Kolkata   448.541497     0.00
# 53                              Duration Source_Mumbai   638.198978     0.00
# 54                         Duration Destination_Cochin   338.964313     0.00
# 55                          Duration Destination_Delhi   747.224286     0.00
# 56                      Duration Destination_Hyderabad   638.198978     0.00
# 57                        Duration Destination_Kolkata   226.686441     0.00
# 58                      Duration Destination_New Delhi   101.926641     0.00
# 59                                  Duration IsWeekend   593.375920     0.00
# 60                                       Total_Stops^2  2095.185466     0.00
# 61                                Total_Stops Dep_hour  2802.366794     0.00
# 62                              Total_Stops Dep_minute  1316.457912     0.00
# 63                                Total_Stops Arr_hour  1791.721561     0.00
# 64                              Total_Stops Arr_minute  1598.147892     0.00
# 65                    Total_Stops Date_of_Journey_Year  4080.632555     0.00
# 66                   Total_Stops Date_of_Journey_Month  2642.705111     0.00
# 67                     Total_Stops Date_of_Journey_Day   894.140431     0.00
# 68                       Total_Stops Airline_Air India   232.596158     0.00
# 69                           Total_Stops Airline_GoAir    18.072299     0.00
# 70                          Total_Stops Airline_IndiGo   105.512880     0.00
# 71                     Total_Stops Airline_Jet Airways  2342.252349     0.00
# 72            Total_Stops Airline_Jet Airways Business   466.520730     0.00
# 73               Total_Stops Airline_Multiple carriers   172.922630     0.00
# 74   Total_Stops Airline_Multiple carriers Premium ...     2.045936     0.15
# 75                        Total_Stops Airline_SpiceJet    21.899024     0.00
# 76                          Total_Stops Airline_Trujet          NaN      NaN
# 77                         Total_Stops Airline_Vistara     1.993385     0.16
# 78         Total_Stops Airline_Vistara Premium economy          NaN      NaN
# 79                          Total_Stops Source_Chennai          NaN      NaN
# 80                            Total_Stops Source_Delhi   806.357992     0.00
# 81                          Total_Stops Source_Kolkata   284.864424     0.00
# 82                           Total_Stops Source_Mumbai    96.046408     0.00
# 83                      Total_Stops Destination_Cochin   806.357992     0.00
# 84                       Total_Stops Destination_Delhi          NaN      NaN
# 85                   Total_Stops Destination_Hyderabad    96.046408     0.00
# 86                     Total_Stops Destination_Kolkata          NaN      NaN
# 87                   Total_Stops Destination_New Delhi   515.926325     0.00
# 88                               Total_Stops IsWeekend   490.632509     0.00
# 89                                          Dep_hour^2     0.032314     0.86
# 90                                 Dep_hour Dep_minute     0.024352     0.88
# 91                                   Dep_hour Arr_hour     1.141201     0.29
# 92                                 Dep_hour Arr_minute    31.573460     0.00
# 93                       Dep_hour Date_of_Journey_Year     1.997667     0.16
# 94                      Dep_hour Date_of_Journey_Month    10.043484     0.00
# 95                        Dep_hour Date_of_Journey_Day    75.668550     0.00
# 96                          Dep_hour Airline_Air India     2.386839     0.12
# 97                              Dep_hour Airline_GoAir    49.662387     0.00
# 98                             Dep_hour Airline_IndiGo   832.831327     0.00
# 99                        Dep_hour Airline_Jet Airways  1305.508652     0.00
# 100              Dep_hour Airline_Jet Airways Business   355.820851     0.00
# 101                 Dep_hour Airline_Multiple carriers   140.175278     0.00
# 102  Dep_hour Airline_Multiple carriers Premium eco...     1.532367     0.22
# 103                          Dep_hour Airline_SpiceJet   549.610840     0.00
# 104                            Dep_hour Airline_Trujet          NaN      NaN
# 105                           Dep_hour Airline_Vistara    21.230184     0.00
# 106           Dep_hour Airline_Vistara Premium economy     0.011756     0.91
# 107                            Dep_hour Source_Chennai   171.215842     0.00
# 108                              Dep_hour Source_Delhi   469.230329     0.00
# 109                            Dep_hour Source_Kolkata     0.239065     0.62
# 110                             Dep_hour Source_Mumbai   344.852338     0.00
# 111                        Dep_hour Destination_Cochin   469.230329     0.00
# 112                         Dep_hour Destination_Delhi   557.685443     0.00
# 113                     Dep_hour Destination_Hyderabad   344.852338     0.00
# 114                       Dep_hour Destination_Kolkata   171.215842     0.00
# 115                     Dep_hour Destination_New Delhi   284.718061     0.00
# 116                                 Dep_hour IsWeekend     2.762756     0.10
# 117                                       Dep_minute^2     0.152149     0.70
# 118                                Dep_minute Arr_hour     0.821030     0.36
# 119                              Dep_minute Arr_minute    11.135228     0.00
# 120                    Dep_minute Date_of_Journey_Year     4.815703     0.03
# 121                   Dep_minute Date_of_Journey_Month    44.180508     0.00
# 122                     Dep_minute Date_of_Journey_Day   111.655457     0.00
# 123                       Dep_minute Airline_Air India    37.048816     0.00
# 124                           Dep_minute Airline_GoAir    63.601023     0.00
# 125                          Dep_minute Airline_IndiGo   593.948458     0.00
# 126                     Dep_minute Airline_Jet Airways   774.670215     0.00
# 127            Dep_minute Airline_Jet Airways Business   474.176771     0.00
# 128               Dep_minute Airline_Multiple carriers    36.773488     0.00
# 129  Dep_minute Airline_Multiple carriers Premium e...     0.862595     0.35
# 130                        Dep_minute Airline_SpiceJet   486.492423     0.00
# 131                          Dep_minute Airline_Trujet          NaN      NaN
# 132                         Dep_minute Airline_Vistara     4.691278     0.03
# 133         Dep_minute Airline_Vistara Premium economy     0.424176     0.51
# 134                          Dep_minute Source_Chennai   167.497545     0.00
# 135                            Dep_minute Source_Delhi   149.790175     0.00
# 136                          Dep_minute Source_Kolkata     0.032252     0.86
# 137                           Dep_minute Source_Mumbai   267.681131     0.00
# 138                      Dep_minute Destination_Cochin   149.790175     0.00
# 139                       Dep_minute Destination_Delhi   422.415129     0.00
# 140                   Dep_minute Destination_Hyderabad   267.681131     0.00
# 141                     Dep_minute Destination_Kolkata   167.497545     0.00
# 142                   Dep_minute Destination_New Delhi   322.922304     0.00
# 143                               Dep_minute IsWeekend     0.118443     0.73
# 144                                         Arr_hour^2     4.449299     0.03
# 145                                Arr_hour Arr_minute    62.590604     0.00
# 146                      Arr_hour Date_of_Journey_Year     7.350185     0.01
# 147                     Arr_hour Date_of_Journey_Month     2.300741     0.13
# 148                       Arr_hour Date_of_Journey_Day    61.582137     0.00
# 149                         Arr_hour Airline_Air India     8.473654     0.00
# 150                             Arr_hour Airline_GoAir    60.804760     0.00
# 151                            Arr_hour Airline_IndiGo   691.563571     0.00
# 152                       Arr_hour Airline_Jet Airways   984.248157     0.00
# 153              Arr_hour Airline_Jet Airways Business   536.306534     0.00
# 154                 Arr_hour Airline_Multiple carriers    96.661217     0.00
# 155  Arr_hour Airline_Multiple carriers Premium eco...     1.591182     0.21
# 156                          Arr_hour Airline_SpiceJet   383.714402     0.00
# 157                            Arr_hour Airline_Trujet          NaN      NaN
# 158                           Arr_hour Airline_Vistara    20.050949     0.00
# 159           Arr_hour Airline_Vistara Premium economy     0.003536     0.95
# 160                            Arr_hour Source_Chennai   174.971800     0.00
# 161                              Arr_hour Source_Delhi   272.289124     0.00
# 162                            Arr_hour Source_Kolkata     6.832578     0.01
# 163                             Arr_hour Source_Mumbai   256.067944     0.00
# 164                        Arr_hour Destination_Cochin   272.289124     0.00
# 165                         Arr_hour Destination_Delhi   476.748753     0.00
# 166                     Arr_hour Destination_Hyderabad   256.067944     0.00
# 167                       Arr_hour Destination_Kolkata   174.971800     0.00
# 168                     Arr_hour Destination_New Delhi   213.074099     0.00
# 169                                 Arr_hour IsWeekend     9.420587     0.00
# 170                                       Arr_minute^2    56.149649     0.00
# 171                    Arr_minute Date_of_Journey_Year    50.117144     0.00
# 172                   Arr_minute Date_of_Journey_Month   139.450278     0.00
# 173                     Arr_minute Date_of_Journey_Day   208.589300     0.00
# 174                       Arr_minute Airline_Air India    11.272278     0.00
# 175                           Arr_minute Airline_GoAir    67.262123     0.00
# 176                          Arr_minute Airline_IndiGo   706.868143     0.00
# 177                     Arr_minute Airline_Jet Airways   765.819911     0.00
# 178            Arr_minute Airline_Jet Airways Business   524.788296     0.00
# 179               Arr_minute Airline_Multiple carriers   114.902628     0.00
# 180  Arr_minute Airline_Multiple carriers Premium e...     2.808500     0.09
# 181                        Arr_minute Airline_SpiceJet   481.842854     0.00
# 182                          Arr_minute Airline_Trujet          NaN      NaN
# 183                         Arr_minute Airline_Vistara    24.633339     0.00
# 184         Arr_minute Airline_Vistara Premium economy     0.028980     0.86
# 185                          Arr_minute Source_Chennai   130.725402     0.00
# 186                            Arr_minute Source_Delhi   250.877632     0.00
# 187                          Arr_minute Source_Kolkata     0.591614     0.44
# 188                           Arr_minute Source_Mumbai   240.237124     0.00
# 189                      Arr_minute Destination_Cochin   250.877632     0.00
# 190                       Arr_minute Destination_Delhi   503.192170     0.00
# 191                   Arr_minute Destination_Hyderabad   240.237124     0.00
# 192                     Arr_minute Destination_Kolkata   130.725402     0.00
# 193                   Arr_minute Destination_New Delhi   171.890256     0.00
# 194                               Arr_minute IsWeekend     0.357303     0.55
# 195                             Date_of_Journey_Year^2          NaN      NaN
# 196         Date_of_Journey_Year Date_of_Journey_Month   105.001763     0.00
# 197           Date_of_Journey_Year Date_of_Journey_Day   190.704621     0.00
# 198             Date_of_Journey_Year Airline_Air India    16.872350     0.00
# 199                 Date_of_Journey_Year Airline_GoAir    65.676054     0.00
# 200                Date_of_Journey_Year Airline_IndiGo  1067.178466     0.00
# 201           Date_of_Journey_Year Airline_Jet Airways  1530.357449     0.00
# 202  Date_of_Journey_Year Airline_Jet Airways Business   586.830491     0.00
# 203     Date_of_Journey_Year Airline_Multiple carriers   157.133032     0.00
# 204  Date_of_Journey_Year Airline_Multiple carriers...     2.045936     0.15
# 205              Date_of_Journey_Year Airline_SpiceJet   685.138075     0.00
# 206                Date_of_Journey_Year Airline_Trujet          NaN      NaN
# 207               Date_of_Journey_Year Airline_Vistara    30.835972     0.00
# 208  Date_of_Journey_Year Airline_Vistara Premium e...     0.001145     0.97
# 209                Date_of_Journey_Year Source_Chennai   226.644207     0.00
# 210                  Date_of_Journey_Year Source_Delhi   484.426614     0.00
# 211                Date_of_Journey_Year Source_Kolkata     2.352964     0.13
# 212                 Date_of_Journey_Year Source_Mumbai   404.502471     0.00
# 213            Date_of_Journey_Year Destination_Cochin   484.426614     0.00
# 214             Date_of_Journey_Year Destination_Delhi   744.714290     0.00
# 215         Date_of_Journey_Year Destination_Hyderabad   404.502471     0.00
# 216           Date_of_Journey_Year Destination_Kolkata   226.644207     0.00
# 217         Date_of_Journey_Year Destination_New Delhi   302.040290     0.00
# 218                     Date_of_Journey_Year IsWeekend     4.166383     0.04
# 219                            Date_of_Journey_Month^2    83.942348     0.00
# 220          Date_of_Journey_Month Date_of_Journey_Day   158.537405     0.00
# 221            Date_of_Journey_Month Airline_Air India     9.992901     0.00
# 222                Date_of_Journey_Month Airline_GoAir    68.910175     0.00
# 223               Date_of_Journey_Month Airline_IndiGo  1119.374441     0.00
# 224          Date_of_Journey_Month Airline_Jet Airways  1186.930072     0.00
# 225  Date_of_Journey_Month Airline_Jet Airways Busi...   586.830491     0.00
# 226    Date_of_Journey_Month Airline_Multiple carriers   112.971839     0.00
# 227  Date_of_Journey_Month Airline_Multiple carrier...     2.045936     0.15
# 228             Date_of_Journey_Month Airline_SpiceJet   678.563244     0.00
# 229               Date_of_Journey_Month Airline_Trujet          NaN      NaN
# 230              Date_of_Journey_Month Airline_Vistara    38.152306     0.00
# 231  Date_of_Journey_Month Airline_Vistara Premium ...     0.020690     0.89
# 232               Date_of_Journey_Month Source_Chennai   228.696892     0.00
# 233                 Date_of_Journey_Month Source_Delhi   392.507187     0.00
# 234               Date_of_Journey_Month Source_Kolkata     6.440577     0.01
# 235                Date_of_Journey_Month Source_Mumbai   483.928835     0.00
# 236           Date_of_Journey_Month Destination_Cochin   392.507187     0.00
# 237            Date_of_Journey_Month Destination_Delhi   711.627195     0.00
# 238        Date_of_Journey_Month Destination_Hyderabad   483.928835     0.00
# 239          Date_of_Journey_Month Destination_Kolkata   228.696892     0.00
# 240        Date_of_Journey_Month Destination_New Delhi   302.040290     0.00
# 241                    Date_of_Journey_Month IsWeekend     0.854399     0.36
# 242                              Date_of_Journey_Day^2   158.768207     0.00
# 243              Date_of_Journey_Day Airline_Air India     0.026683     0.87
# 244                  Date_of_Journey_Day Airline_GoAir    53.895757     0.00
# 245                 Date_of_Journey_Day Airline_IndiGo   803.110708     0.00
# 246            Date_of_Journey_Day Airline_Jet Airways   607.725836     0.00
# 247   Date_of_Journey_Day Airline_Jet Airways Business   284.560854     0.00
# 248      Date_of_Journey_Day Airline_Multiple carriers    42.609776     0.00
# 249  Date_of_Journey_Day Airline_Multiple carriers ...     2.045936     0.15
# 250               Date_of_Journey_Day Airline_SpiceJet   519.114881     0.00
# 251                 Date_of_Journey_Day Airline_Trujet          NaN      NaN
# 252                Date_of_Journey_Day Airline_Vistara    29.819817     0.00
# 253  Date_of_Journey_Day Airline_Vistara Premium ec...     0.104766     0.75
# 254                 Date_of_Journey_Day Source_Chennai   191.108871     0.00
# 255                   Date_of_Journey_Day Source_Delhi   126.328453     0.00
# 256                 Date_of_Journey_Day Source_Kolkata     1.837518     0.18
# 257                  Date_of_Journey_Day Source_Mumbai   392.113688     0.00
# 258             Date_of_Journey_Day Destination_Cochin   126.328453     0.00
# 259              Date_of_Journey_Day Destination_Delhi   505.469757     0.00
# 260          Date_of_Journey_Day Destination_Hyderabad   392.113688     0.00
# 261            Date_of_Journey_Day Destination_Kolkata   191.108871     0.00
# 262          Date_of_Journey_Day Destination_New Delhi     2.234223     0.14
# 263                      Date_of_Journey_Day IsWeekend     3.938437     0.05
# 264                                Airline_Air India^2    16.872350     0.00
# 265                    Airline_Air India Airline_GoAir          NaN      NaN
# 266                   Airline_Air India Airline_IndiGo          NaN      NaN
# 267              Airline_Air India Airline_Jet Airways          NaN      NaN
# 268     Airline_Air India Airline_Jet Airways Business          NaN      NaN
# 269        Airline_Air India Airline_Multiple carriers          NaN      NaN
# 270  Airline_Air India Airline_Multiple carriers Pr...          NaN      NaN
# 271                 Airline_Air India Airline_SpiceJet          NaN      NaN
# 272                   Airline_Air India Airline_Trujet          NaN      NaN
# 273                  Airline_Air India Airline_Vistara          NaN      NaN
# 274  Airline_Air India Airline_Vistara Premium economy          NaN      NaN
# 275                   Airline_Air India Source_Chennai     6.368309     0.01
# 276                     Airline_Air India Source_Delhi    18.686328     0.00
# 277                   Airline_Air India Source_Kolkata    26.293951     0.00
# 278                    Airline_Air India Source_Mumbai    36.448423     0.00
# 279               Airline_Air India Destination_Cochin    18.686328     0.00
# 280                Airline_Air India Destination_Delhi    35.029927     0.00
# 281            Airline_Air India Destination_Hyderabad    36.448423     0.00
# 282              Airline_Air India Destination_Kolkata     6.368309     0.01
# 283            Airline_Air India Destination_New Delhi    32.038958     0.00
# 284                        Airline_Air India IsWeekend     6.396306     0.01
# 285                                    Airline_GoAir^2    65.676054     0.00
# 286                       Airline_GoAir Airline_IndiGo          NaN      NaN
# 287                  Airline_GoAir Airline_Jet Airways          NaN      NaN
# 288         Airline_GoAir Airline_Jet Airways Business          NaN      NaN
# 289            Airline_GoAir Airline_Multiple carriers          NaN      NaN
# 290  Airline_GoAir Airline_Multiple carriers Premiu...          NaN      NaN
# 291                     Airline_GoAir Airline_SpiceJet          NaN      NaN
# 292                       Airline_GoAir Airline_Trujet          NaN      NaN
# 293                      Airline_GoAir Airline_Vistara          NaN      NaN
# 294      Airline_GoAir Airline_Vistara Premium economy          NaN      NaN
# 295                       Airline_GoAir Source_Chennai          NaN      NaN
# 296                         Airline_GoAir Source_Delhi    17.196054     0.00
# 297                       Airline_GoAir Source_Kolkata     3.775914     0.05
# 298                        Airline_GoAir Source_Mumbai          NaN      NaN
# 299                   Airline_GoAir Destination_Cochin    17.196054     0.00
# 300                    Airline_GoAir Destination_Delhi    50.857638     0.00
# 301                Airline_GoAir Destination_Hyderabad          NaN      NaN
# 302                  Airline_GoAir Destination_Kolkata          NaN      NaN
# 303                Airline_GoAir Destination_New Delhi     2.670131     0.10
# 304                            Airline_GoAir IsWeekend    15.498902     0.00
# 305                                   Airline_IndiGo^2  1067.178466     0.00
# 306                 Airline_IndiGo Airline_Jet Airways          NaN      NaN
# 307        Airline_IndiGo Airline_Jet Airways Business          NaN      NaN
# 308           Airline_IndiGo Airline_Multiple carriers          NaN      NaN
# 309  Airline_IndiGo Airline_Multiple carriers Premi...          NaN      NaN
# 310                    Airline_IndiGo Airline_SpiceJet          NaN      NaN
# 311                      Airline_IndiGo Airline_Trujet          NaN      NaN
# 312                     Airline_IndiGo Airline_Vistara          NaN      NaN
# 313     Airline_IndiGo Airline_Vistara Premium economy          NaN      NaN
# 314                      Airline_IndiGo Source_Chennai   126.946917     0.00
# 315                        Airline_IndiGo Source_Delhi    89.567808     0.00
# 316                      Airline_IndiGo Source_Kolkata   240.820669     0.00
# 317                       Airline_IndiGo Source_Mumbai   202.815063     0.00
# 318                  Airline_IndiGo Destination_Cochin    89.567808     0.00
# 319                   Airline_IndiGo Destination_Delhi   256.654810     0.00
# 320               Airline_IndiGo Destination_Hyderabad   202.815063     0.00
# 321                 Airline_IndiGo Destination_Kolkata   126.946917     0.00
# 322               Airline_IndiGo Destination_New Delhi    13.227283     0.00
# 323                           Airline_IndiGo IsWeekend   198.009313     0.00
# 324                              Airline_Jet Airways^2  1530.357449     0.00
# 325   Airline_Jet Airways Airline_Jet Airways Business          NaN      NaN
# 326      Airline_Jet Airways Airline_Multiple carriers          NaN      NaN
# 327  Airline_Jet Airways Airline_Multiple carriers ...          NaN      NaN
# 328               Airline_Jet Airways Airline_SpiceJet          NaN      NaN
# 329                 Airline_Jet Airways Airline_Trujet          NaN      NaN
# 330                Airline_Jet Airways Airline_Vistara          NaN      NaN
# 331  Airline_Jet Airways Airline_Vistara Premium ec...          NaN      NaN
# 332                 Airline_Jet Airways Source_Chennai          NaN      NaN
# 333                   Airline_Jet Airways Source_Delhi   749.051831     0.00
# 334                 Airline_Jet Airways Source_Kolkata   366.398673     0.00
# 335                  Airline_Jet Airways Source_Mumbai    45.512228     0.00
# 336             Airline_Jet Airways Destination_Cochin   749.051831     0.00
# 337              Airline_Jet Airways Destination_Delhi    77.330077     0.00
# 338          Airline_Jet Airways Destination_Hyderabad    45.512228     0.00
# 339            Airline_Jet Airways Destination_Kolkata          NaN      NaN
# 340          Airline_Jet Airways Destination_New Delhi   551.879132     0.00
# 341                      Airline_Jet Airways IsWeekend   258.324006     0.00
# 342                     Airline_Jet Airways Business^2   586.830491     0.00
# 343  Airline_Jet Airways Business Airline_Multiple ...          NaN      NaN
# 344  Airline_Jet Airways Business Airline_Multiple ...          NaN      NaN
# 345      Airline_Jet Airways Business Airline_SpiceJet          NaN      NaN
# 346        Airline_Jet Airways Business Airline_Trujet          NaN      NaN
# 347       Airline_Jet Airways Business Airline_Vistara          NaN      NaN
# 348  Airline_Jet Airways Business Airline_Vistara P...          NaN      NaN
# 349        Airline_Jet Airways Business Source_Chennai          NaN      NaN
# 350          Airline_Jet Airways Business Source_Delhi   153.436285     0.00
# 351        Airline_Jet Airways Business Source_Kolkata          NaN      NaN
# 352         Airline_Jet Airways Business Source_Mumbai          NaN      NaN
# 353    Airline_Jet Airways Business Destination_Cochin   153.436285     0.00
# 354     Airline_Jet Airways Business Destination_Delhi          NaN      NaN
# 355  Airline_Jet Airways Business Destination_Hyder...          NaN      NaN
# 356   Airline_Jet Airways Business Destination_Kolkata          NaN      NaN
# 357  Airline_Jet Airways Business Destination_New D...   426.559117     0.00
# 358             Airline_Jet Airways Business IsWeekend    65.303401     0.00
# 359                        Airline_Multiple carriers^2   157.133032     0.00
# 360  Airline_Multiple carriers Airline_Multiple car...          NaN      NaN
# 361         Airline_Multiple carriers Airline_SpiceJet          NaN      NaN
# 362           Airline_Multiple carriers Airline_Trujet          NaN      NaN
# 363          Airline_Multiple carriers Airline_Vistara          NaN      NaN
# 364  Airline_Multiple carriers Airline_Vistara Prem...          NaN      NaN
# 365           Airline_Multiple carriers Source_Chennai          NaN      NaN
# 366             Airline_Multiple carriers Source_Delhi   157.133032     0.00
# 367           Airline_Multiple carriers Source_Kolkata          NaN      NaN
# 368            Airline_Multiple carriers Source_Mumbai          NaN      NaN
# 369       Airline_Multiple carriers Destination_Cochin   157.133032     0.00
# 370        Airline_Multiple carriers Destination_Delhi          NaN      NaN
# 371    Airline_Multiple carriers Destination_Hyderabad          NaN      NaN
# 372      Airline_Multiple carriers Destination_Kolkata          NaN      NaN
# 373    Airline_Multiple carriers Destination_New Delhi          NaN      NaN
# 374                Airline_Multiple carriers IsWeekend    93.554359     0.00
# 375        Airline_Multiple carriers Premium economy^2     2.045936     0.15
# 376  Airline_Multiple carriers Premium economy Airl...          NaN      NaN
# 377  Airline_Multiple carriers Premium economy Airl...          NaN      NaN
# 378  Airline_Multiple carriers Premium economy Airl...          NaN      NaN
# 379  Airline_Multiple carriers Premium economy Airl...          NaN      NaN
# 380  Airline_Multiple carriers Premium economy Sour...          NaN      NaN
# 381  Airline_Multiple carriers Premium economy Sour...     2.045936     0.15
# 382  Airline_Multiple carriers Premium economy Sour...          NaN      NaN
# 383  Airline_Multiple carriers Premium economy Sour...          NaN      NaN
# 384  Airline_Multiple carriers Premium economy Dest...     2.045936     0.15
# 385  Airline_Multiple carriers Premium economy Dest...          NaN      NaN
# 386  Airline_Multiple carriers Premium economy Dest...          NaN      NaN
# 387  Airline_Multiple carriers Premium economy Dest...          NaN      NaN
# 388  Airline_Multiple carriers Premium economy Dest...          NaN      NaN
# 389  Airline_Multiple carriers Premium economy IsWe...          NaN      NaN
# 390                                 Airline_SpiceJet^2   685.138075     0.00
# 391                    Airline_SpiceJet Airline_Trujet          NaN      NaN
# 392                   Airline_SpiceJet Airline_Vistara          NaN      NaN
# 393   Airline_SpiceJet Airline_Vistara Premium economy          NaN      NaN
# 394                    Airline_SpiceJet Source_Chennai   103.101595     0.00
# 395                      Airline_SpiceJet Source_Delhi    27.998687     0.00
# 396                    Airline_SpiceJet Source_Kolkata   193.903371     0.00
# 397                     Airline_SpiceJet Source_Mumbai   186.194328     0.00
# 398                Airline_SpiceJet Destination_Cochin    27.998687     0.00
# 399                 Airline_SpiceJet Destination_Delhi   111.040535     0.00
# 400             Airline_SpiceJet Destination_Hyderabad   186.194328     0.00
# 401               Airline_SpiceJet Destination_Kolkata   103.101595     0.00
# 402             Airline_SpiceJet Destination_New Delhi     8.982875     0.00
# 403                         Airline_SpiceJet IsWeekend   130.481172     0.00
# 404                                   Airline_Trujet^2          NaN      NaN
# 405                     Airline_Trujet Airline_Vistara          NaN      NaN
# 406     Airline_Trujet Airline_Vistara Premium economy          NaN      NaN
# 407                      Airline_Trujet Source_Chennai          NaN      NaN
# 408                        Airline_Trujet Source_Delhi          NaN      NaN
# 409                      Airline_Trujet Source_Kolkata          NaN      NaN
# 410                       Airline_Trujet Source_Mumbai          NaN      NaN
# 411                  Airline_Trujet Destination_Cochin          NaN      NaN
# 412                   Airline_Trujet Destination_Delhi          NaN      NaN
# 413               Airline_Trujet Destination_Hyderabad          NaN      NaN
# 414                 Airline_Trujet Destination_Kolkata          NaN      NaN
# 415               Airline_Trujet Destination_New Delhi          NaN      NaN
# 416                           Airline_Trujet IsWeekend          NaN      NaN
# 417                                  Airline_Vistara^2    30.835972     0.00
# 418    Airline_Vistara Airline_Vistara Premium economy          NaN      NaN
# 419                     Airline_Vistara Source_Chennai     1.824936     0.18
# 420                       Airline_Vistara Source_Delhi    10.300999     0.00
# 421                     Airline_Vistara Source_Kolkata     0.133545     0.71
# 422                      Airline_Vistara Source_Mumbai     8.411068     0.00
# 423                 Airline_Vistara Destination_Cochin    10.300999     0.00
# 424                  Airline_Vistara Destination_Delhi    75.355834     0.00
# 425              Airline_Vistara Destination_Hyderabad     8.411068     0.00
# 426                Airline_Vistara Destination_Kolkata     1.824936     0.18
# 427              Airline_Vistara Destination_New Delhi     0.887403     0.35
# 428                          Airline_Vistara IsWeekend     4.509197     0.03
# 429                  Airline_Vistara Premium economy^2     0.001145     0.97
# 430     Airline_Vistara Premium economy Source_Chennai     0.000238     0.99
# 431       Airline_Vistara Premium economy Source_Delhi          NaN      NaN
# 432     Airline_Vistara Premium economy Source_Kolkata          NaN      NaN
# 433      Airline_Vistara Premium economy Source_Mumbai          NaN      NaN
# 434  Airline_Vistara Premium economy Destination_Co...          NaN      NaN
# 435  Airline_Vistara Premium economy Destination_Delhi     0.439342     0.51
# 436  Airline_Vistara Premium economy Destination_Hy...          NaN      NaN
# 437  Airline_Vistara Premium economy Destination_Ko...     0.000238     0.99
# 438  Airline_Vistara Premium economy Destination_Ne...     0.346681     0.56
# 439          Airline_Vistara Premium economy IsWeekend     0.002740     0.96
# 440                                   Source_Chennai^2   226.644207     0.00
# 441                        Source_Chennai Source_Delhi          NaN      NaN
# 442                      Source_Chennai Source_Kolkata          NaN      NaN
# 443                       Source_Chennai Source_Mumbai          NaN      NaN
# 444                  Source_Chennai Destination_Cochin          NaN      NaN
# 445                   Source_Chennai Destination_Delhi          NaN      NaN
# 446               Source_Chennai Destination_Hyderabad          NaN      NaN
# 447                 Source_Chennai Destination_Kolkata   226.644207     0.00
# 448               Source_Chennai Destination_New Delhi          NaN      NaN
# 449                           Source_Chennai IsWeekend    50.370959     0.00
# 450                                     Source_Delhi^2   484.426614     0.00
# 451                        Source_Delhi Source_Kolkata          NaN      NaN
# 452                         Source_Delhi Source_Mumbai          NaN      NaN
# 453                    Source_Delhi Destination_Cochin   484.426614     0.00
# 454                     Source_Delhi Destination_Delhi          NaN      NaN
# 455                 Source_Delhi Destination_Hyderabad          NaN      NaN
# 456                   Source_Delhi Destination_Kolkata          NaN      NaN
# 457                 Source_Delhi Destination_New Delhi          NaN      NaN
# 458                             Source_Delhi IsWeekend   213.052164     0.00
# 459                                   Source_Kolkata^2     2.352964     0.13
# 460                       Source_Kolkata Source_Mumbai          NaN      NaN
# 461                  Source_Kolkata Destination_Cochin          NaN      NaN
# 462                   Source_Kolkata Destination_Delhi          NaN      NaN
# 463               Source_Kolkata Destination_Hyderabad          NaN      NaN
# 464                 Source_Kolkata Destination_Kolkata          NaN      NaN
# 465               Source_Kolkata Destination_New Delhi          NaN      NaN
# 466                           Source_Kolkata IsWeekend    16.857980     0.00
# 467                                    Source_Mumbai^2   404.502471     0.00
# 468                   Source_Mumbai Destination_Cochin          NaN      NaN
# 469                    Source_Mumbai Destination_Delhi          NaN      NaN
# 470                Source_Mumbai Destination_Hyderabad   404.502471     0.00
# 471                  Source_Mumbai Destination_Kolkata          NaN      NaN
# 472                Source_Mumbai Destination_New Delhi          NaN      NaN
# 473                            Source_Mumbai IsWeekend   153.888397     0.00
# 474                               Destination_Cochin^2   484.426614     0.00
# 475               Destination_Cochin Destination_Delhi          NaN      NaN
# 476           Destination_Cochin Destination_Hyderabad          NaN      NaN
# 477             Destination_Cochin Destination_Kolkata          NaN      NaN
# 478           Destination_Cochin Destination_New Delhi          NaN      NaN
# 479                       Destination_Cochin IsWeekend   213.052164     0.00
# 480                                Destination_Delhi^2   744.714290     0.00
# 481            Destination_Delhi Destination_Hyderabad          NaN      NaN
# 482              Destination_Delhi Destination_Kolkata          NaN      NaN
# 483            Destination_Delhi Destination_New Delhi          NaN      NaN
# 484                        Destination_Delhi IsWeekend   153.253709     0.00
# 485                            Destination_Hyderabad^2   404.502471     0.00
# 486          Destination_Hyderabad Destination_Kolkata          NaN      NaN
# 487        Destination_Hyderabad Destination_New Delhi          NaN      NaN
# 488                    Destination_Hyderabad IsWeekend   153.888397     0.00
# 489                              Destination_Kolkata^2   226.644207     0.00
# 490          Destination_Kolkata Destination_New Delhi          NaN      NaN
# 491                      Destination_Kolkata IsWeekend    50.370959     0.00
# 492                            Destination_New Delhi^2   302.040290     0.00
# 493                    Destination_New Delhi IsWeekend    13.395025     0.00
# 494                                        IsWeekend^2     4.166383     0.04
# 147

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest, SelectFwe
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

transformer = PolynomialFeatures(degree=2, include_bias=False)
best = SelectFwe(f_regression, alpha=0.05)
estimator = LinearRegression()

pipeline = Pipeline([ ('transformer', transformer), ('feature_selection', best), ('estimator', estimator)])

# fit the regression on the training data
pipeline.fit(data_train_poly, target_train_poly)

# predict the values for the test data
predictions = pipeline.predict(data_test_poly)

# evaluate using different measures
mse = mean_squared_error(target_test_poly, predictions)
r2 = r2_score(target_test_poly, predictions)

print("MSE:", mse)
print("RMSE:", sqrt(mse))
print("R^2:", r2)
# Out:
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:284: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means ** 2)
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: divide by zero encountered in true_divide
#   correlation_coefficient /= X_norms
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms
# /Users/kevin/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:358: RuntimeWarning: invalid value encountered in true_divide
#   f_statistic = corr_coef_squared / (1 - corr_coef_squared) * deg_of_freedom
# MSE: 6542047.250347505
# RMSE: 2557.742608306689
# R^2: 0.6850028199290099

# %%
# get the selected features
# selected_features = pipeline.named_steps['feature_selection'].get_support()

# print the selected variables
# for i, f in enumerate(pipeline.named_steps['transformer'].get_feature_names_out(data_train_poly.columns)):
#     if selected_features[i]:
#         print(f)
